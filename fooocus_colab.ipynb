# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 22.2 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.35 MiB | 29.96 MiB/s, done.
# Resolving deltas: 100% (3839/3839), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 11.5MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 9.97MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 101MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 244MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:47<00:00, 148MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:06<00:00, 7.92MB/s]
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://e2452defb25c4c752a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetens
# [Fooocus] Preparing Fooocus text #9 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, amazing, flowing, intricate, highly detailed, burning background, divine, dramatic, sharp focus, excellent composition, dynamic, cinematic, beautiful, elegant, rich deep colors, stunning, attractive, futuristic, great, atmosphere, optimistic, vibrant, aesthetic, very
# [Fooocus] Preparing Fooocus text #10 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, amazing, flowing, intricate, elegant, highly detailed, wonderful, glowing, sharp focus, beautiful, dramatic, thought, iconic, epic, cinematic, fine composition, cool, creative, extremely inspirational, clear, brilliant, colorful, magic, surreal, pretty
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding positive #7 ...
# [Fooocus] Encoding positive #8 ...
# [Fooocus] Encoding positive #9 ...
# [Fooocus] Encoding positive #10 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Encoding negative #7 ...
# [Fooocus] Encoding negative #8 ...
# [Fooocus] Encoding negative #9 ...
# [Fooocus] Encoding negative #10 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 9.13 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.79 seconds
# 100% 60/60 [00:52<00:00,  1.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# [Fooocus] Saving image 1/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 57.58 seconds
# [Fooocus] Preparing task 2/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# 100% 60/60 [00:51<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 54.68 seconds
# [Fooocus] Preparing task 3/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:52<00:00,  1.15it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 3/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 55.18 seconds
# [Fooocus] Preparing task 4/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# 100% 60/60 [00:51<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 4/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 54.77 seconds
# [Fooocus] Preparing task 5/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
#  22% 13/60 [00:12<00:43,  1.08it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 234.91 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 244.10 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5053609264951468326
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely nice, warm colors, sharp focus, graceful, dynamic background, professional, cinematic, modern fine composition, beautiful dramatic colorful rich vivid color, ambient atmosphere
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, wonderful cinematic color, dramatic shining, sharp focus, perfect composition, aesthetic, great detail, inspirational, cute, artistic, emotional, pretty, fine, inspiring
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely nice, wonderful, delicate, expressive, cute, glowing, sharp focus, vibrant, color, beautiful, designed, complex, exquisite, fine detail
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely rare, beautiful, holy, scenic, sharp focus, divine, dramatic illumination, professional, cute, charming, artistic, expressive, pretty, lush
# [Fooocus] Preparing Fooocus text #5 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely fine detail, colorful, sacred flowing magic, sharp focus, radiant colors, dramatic cinematic, majestic, confident, open glorious, incredible, loving, noble
# [Fooocus] Preparing Fooocus text #6 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, cool, highly detailed, dramatic, dynamic, holy, vibrant, color, shiny, rich deep vivid colors, open loving, beautiful, symmetry, great romantic, elegant, delicate
# [Fooocus] Preparing Fooocus text #7 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely fine detail, sharp focus, color, cinematic, dramatic ambient, dynamic, full background, professional, artistic, great composition, atmosphere, lively, magical
# [Fooocus] Preparing Fooocus text #8 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, wonderful, dramatic, sharp focus, bright colors, striking, beautiful, artistic, fine detail, attractive, complex, elite, surreal, iconic, cute
# [Fooocus] Preparing Fooocus text #9 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, extremely rare, beautiful, epic, dramatic, sharp focus, cinematic, incredible artistic, innocent, very inspirational, cute, creative, vibrant, glowing, amazing
# [Fooocus] Preparing Fooocus text #10 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed sticking a penis in her vagina, intricate, elegant, highly detailed, wonderful, aesthetic, dramatic, sharp focus, illuminated background, epic cinematic composition, joyful, scenic, classic, fine detail, ambient, varied, artistic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding positive #7 ...
# [Fooocus] Encoding positive #8 ...
# [Fooocus] Encoding positive #9 ...
# [Fooocus] Encoding positive #10 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Encoding negative #7 ...
# [Fooocus] Encoding negative #8 ...
# [Fooocus] Encoding negative #9 ...
# [Fooocus] Encoding negative #10 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 5.75 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.22 seconds
# 100% 60/60 [00:52<00:00,  1.14it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 56.36 seconds
# [Fooocus] Preparing task 2/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 60/60 [00:51<00:00,  1.17it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# [Fooocus] Saving image 2/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03
# [Fooocus] Preparing Fooocus text #9 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed having oral sex, highly detailed, very intricate, dramatic ambient, dynamic, thought, imposing, perfect composition, beautiful cinematic color, sharp focus, colorful, best, scientific, elegant, new, symmetry, futuristic, magic
# [Fooocus] Preparing Fooocus text #10 ...
# [Prompt Expansion] 21 year old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts, completely naked on a motel bed having oral sex, very detailed, beautiful, intricate, dramatic open celestial full, highly colorful, cinematic, extremely rare, magical, stunning, sharp focus, great composition, dynamic, atmosphere, rich vivid colors, winning, perfect
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding positive #7 ...
# [Fooocus] Encoding positive #8 ...
# [Fooocus] Encoding positive #9 ...
# [Fooocus] Encoding positive #10 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Encoding negative #7 ...
# [Fooocus] Encoding negative #8 ...
# [Fooocus] Encoding negative #9 ...
# [Fooocus] Encoding negative #10 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 5.40 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.27 seconds
# 100% 60/60 [00:56<00:00,  1.05it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 60.68 seconds
# [Fooocus] Preparing task 2/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:56<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/10 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 59.21 seconds
# [Fooocus] Preparing task 3/10 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
#  73% 44/60 [00:42<00:15,  1.04it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 162.76 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 168.19 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3702142512091717079
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 21 years old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts and a big ass, completely naked on a motel bed having oral sex, intricate, elegant, highly detailed, extremely nice, wonderful, cute, beautiful, dramatic, sharp focus, colorful, artistic, fine detail, great composition, dynamic, ambient background, professional
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 21 years old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts and a big ass, completely naked on a motel bed having oral sex, very detailed, beautiful, intricate, cinematic, stunning, highly enhanced, intense, complex artistic color, bright colors, open background, scenic full, divine, attractive, holy, dramatic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] 21 years old, blonde with light eyes, sculptural body with an angelic and sexy face, with big breasts and a big ass, completely naked on a motel bed having oral sex, very detailed, beautiful, intricate, cinematic, stunning, highly enhanced, quality, colorful, dramatic color, perfect background, fine detail, sharp focus, complex artistic, elegant, calm
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.02 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.26 seconds
# 100% 60/60 [00:56<00:00,  1.05it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 60.67 seconds
# [Fooocus] Preparing task 2/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:55<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 58.89 seconds
# [Fooocus] Preparing task 3/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:56<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 3/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-03-31/log.html
# Generating and saving time: 59.02 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 178.58 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 180.64 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
